# %% [markdown]
# # P05: Congestion Phase Transition
#
# ## Goal
# In this notebook, you will:
# 1. Implement the Nagel-Schreckenberg (NaSch) traffic model (Cellular Automata).
# 2. Simulate traffic flow at different densities $\rho$.
# 3. Plot the Fundamental Diagram (Flow $J$ vs Density $\rho$) and identify the critical density $\rho_c$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
