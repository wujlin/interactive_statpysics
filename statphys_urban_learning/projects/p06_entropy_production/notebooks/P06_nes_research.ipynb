# %% [markdown]
# # P06: A Stationary Distribution Can Hide a Current
#
# ## 1. The Question: What Does a Stationary Distribution Hide?
#
# Two systems can have the same stationary distribution while circulating around state space in opposite directions. State occupancy alone therefore cannot reveal the arrow of time; transition paths can.
#
# For a continuous-time Markov chain, the Markov entropy-production rate $\sigma_{\mathrm M}$ measures this pathwise time-reversal asymmetry. It has the dimensions and interpretation of physical entropy production only when the rates obey local detailed balance.
#
# This notebook will:
# 1. Construct a minimal NESS: a biased three-state loop.
# 2. Calculate its edge current, cycle affinity, and $\sigma_{\mathrm M}$.
# 3. Test one steady-state thermodynamic uncertainty relation (TUR) for a time-integrated jump current. The test concerns this Markov model; it is not, by itself, a statement about the energy cost of a real city.
#
# ### Core Mappings
# | Driven Urban System | Non-Equilibrium Physics |
# | :--- | :--- |
# | Directed Flow (e.g. Ring Road) | Net Current $J$ |
# | Asymmetric Rates ($w_{ij} \neq w_{ji}$) | Broken Detailed Balance |
# | Directional transition bias | Cycle affinity $\mathcal A$ |
# | Sequence-level time asymmetry | Markov EPR proxy $\sigma_{\mathrm M}$ |
# | Reliability (Low variance) | Precision $J^2 / \text{Var}(J)$ |

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# Set seed
np.random.seed(42)

# %% [markdown]
# ## 2. The Minimal NESS Model (3-State Ring)
#
# Consider 3 nodes (Regions A, B, C) in a ring.
# Rates:
# - Clockwise ($k_+$): $A \to B \to C \to A$
# - Counter-Clockwise ($k_-$): $A \leftarrow B \leftarrow C \leftarrow A$
#
# If $k_+ \neq k_-$, Detailed Balance is broken. There is a net current $J = P_{ss}(k_+ - k_-)$.

# %%
# Parameters
k_plus = 10.0  # Driven forward rate
k_minus = 1.0  # Backward rate

# Transition Rate Matrix W (W_ij is j -> i, verify convention!)
# Usually Master Eq: dP/dt = W P
# Here we define W[i, j] as rate FROM j TO i
W = np.zeros((3, 3))

# 0->1, 1->2, 2->0 (Clockwise)
W[1, 0] = k_plus
W[2, 1] = k_plus
W[0, 2] = k_plus

# 0<-1, 1<-2, 2<-0 (Counter-Clockwise)
W[0, 1] = k_minus
W[1, 2] = k_minus
W[2, 0] = k_minus

# Diagonal elements reflect outflow (sum of col must be 0)
for i in range(3):
    W[i, i] = -np.sum(W[:, i])

print("Rate Matrix W:\n", W)

# %% [markdown]
# ## 3. Entropy Production Rate (EPR)
#
# In the analytic notation below, $w_{ij}$ is the rate from $i$ to $j$. (The generator in the code stores the same rate as `W[j, i]` so that $\dot P=WP$.) Define
# $$J_{ij}=P_iw_{ij}-P_jw_{ji}.$$
# Taking $k_B=1$, the Markov entropy-production rate is
# $$ \sigma_{\mathrm M}=\frac12\sum_{i\ne j}J_{ij}\ln\frac{P_iw_{ij}}{P_jw_{ji}}. $$
# For this homogeneous ring, $P_i=1/3$. Every edge carries the same current
# $$J_{\rm edge}=\frac{k_+-k_-}{3},$$
# and the cycle affinity is
# $$\mathcal A_{\rm cyc}=3\ln\frac{k_+}{k_-}.$$
# Hence
# $$\sigma_{\mathrm M}=J_{\rm edge}\mathcal A_{\rm cyc}=(k_+-k_-)\ln\frac{k_+}{k_-}.$$

# %%
# 1. Steady State
# Solve W @ P = 0. 
# Since rates are symmetric per node type, P = [1/3, 1/3, 1/3]
P_ss = np.array([1/3, 1/3, 1/3])

# 2. Calculate Flux J
J_cw = P_ss[0] * k_plus
J_ccw = P_ss[0] * k_minus
J_edge = J_cw - J_ccw
# The signed jump count used below records every clockwise jump as +1.
# Its mean rate is k_plus - k_minus, which is three times the per-edge probability current.
J_jump_theory = k_plus - k_minus

# 3. Calculate EPR (sigma)
# Sum over all links. There are 3 links.
# Contribution per undirected edge: (J_cw - J_ccw) * ln(J_cw / J_ccw)
# It simplifies to: (J_cw - J_ccw) * ln(J_cw / J_ccw)
sigma_per_link = (J_cw - J_ccw) * np.log(J_cw / J_ccw)
sigma_total = 3 * sigma_per_link

print(f"Per-edge probability current J_edge: {J_edge:.4f}")
print(f"Mean signed-jump rate: {J_jump_theory:.4f}")
print(f"Markov entropy-production rate sigma_M: {sigma_total:.4f}")
print("-> Positive sigma_M identifies pathwise time-reversal asymmetry.")

# %% [markdown]
# ## 4. Thermodynamic Uncertainty Relation (TUR)
#
# For a steady continuous-time Markov jump process, let $X_\tau$ be a suitable time-integrated current and $j_\tau=X_\tau/\tau$ its time-averaged rate. The long-time TUR states
# $$ \frac{\operatorname{Var}(j_\tau)}{\langle j_\tau\rangle^2} \ge \frac{2}{\sigma_{\mathrm M} \tau} $$
# or $\mathcal{Q}=\epsilon^2(\sigma_{\mathrm M}\tau)\ge2$.
#
# Within this model class, a current with low relative variance requires a larger $\sigma_{\mathrm M}$. Reading that bound as a real energetic cost additionally requires local detailed balance and a physical identification of the transitions.
#
# The observation time must be fixed for this comparison. We therefore stop every Gillespie trajectory at the same $\tau$ before measuring $j_\tau$.

# %%
def gillespie_flux(observation_time, k_plus, k_minus):
    # Track the signed jump displacement over a fixed observation time.
    rate_sum = k_plus + k_minus
    p_plus = k_plus / rate_sum
    time = 0.0
    net_displacement = 0

    while True:
        next_time = time + np.random.exponential(1 / rate_sum)
        if next_time > observation_time:
            break
        time = next_time
        net_displacement += 1 if np.random.rand() < p_plus else -1

    return net_displacement / observation_time

# Run many trajectories to estimate Variance of J
n_trials = 1000
tau_obs = 50.0
J_samples = []

for _ in range(n_trials):
    J_samples.append(gillespie_flux(tau_obs, k_plus, k_minus))

J_mean = np.mean(J_samples)
J_var = np.var(J_samples)

print(f"Simulated Mean Signed-Jump Rate: {J_mean:.4f} (Theory: {J_jump_theory:.4f})")
print(f"Simulated Var(J): {J_var:.4f}")
print(f"Fixed Observation Time tau: {tau_obs:.4f}")

# Check TUR
# Product Q = epsilon^2 * (sigma * tau)
epsilon_sq = J_var / (J_mean**2)
dissipation = sigma_total * tau_obs
Q = epsilon_sq * dissipation

print(f"\nTUR Product Q: {Q:.4f}")
print(f"Is Q >= 2? {Q >= 2.0}")
if Q >= 2.0:
    print("✅ The TUR bound holds for this simulated model.")
else:
    print("❌ Increase sampling and check the current convention.")
