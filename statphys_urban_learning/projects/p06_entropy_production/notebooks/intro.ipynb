# %% [markdown]
# # P06: Entropy Production in NESS
#
# ## Goal
# In this notebook, you will:
# 1. Define a Markov process with non-reversible transition rates (biased loop).
# 2. Calculate the Non-Equilibrium Steady State (NESS) distribution.
# 3. Compute the Entropy Production Rate (EPR) as a measure of irreversibility.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg
