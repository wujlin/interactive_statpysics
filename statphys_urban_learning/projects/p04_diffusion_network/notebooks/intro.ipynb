# %% [markdown]
# # P04: Random Walk on Networks
#
# ## Goal
# In this notebook, you will:
# 1. Simulate random walks on a 2D grid and a graph network.
# 2. Visualize the diffusion process (heatmap evolution).
# 3. Verify the relationship between diffusion coefficient $D$ and mean squared displacement $\langle r^2 \rangle$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
