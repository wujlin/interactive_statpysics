# %% [markdown]
# # P02: Logit Choice & Boltzmann Distribution
#
# ## Goal
# In this notebook, you will:
# 1. Simulate a destination choice process using the Logit model.
# 2. Verify that `Logit` in economics is mathematically identical to `Boltzmann distribution` in physics.
# 3. Estimate the parameter $\beta$ (sensitivity to cost) from synthetic data using Maximum Likelihood Estimation (MLE).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
