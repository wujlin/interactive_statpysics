# %% [markdown]
# # E07 Ising 临界信号：峰值/交点/数据塌缩（有限尺寸标度）
#
# > 目标：在有限尺寸模拟中，用“峰值/交点/塌缩”识别临界附近行为，并亲手跑一遍有限尺寸标度（FSS）的最小操作闭环。
#
# 我们计算三个量（每自旋）：
# - 每自旋热容：\(C_V/N = k_B\beta^2 N\,\mathrm{Var}(e)\)
# - 每自旋易感性：\(\chi = \beta N\,\mathrm{Var}(m)\)
# - Binder cumulant：\(U = 1 - \langle m^4\rangle / (3\langle m^2\rangle^2)\)

# %%
import os
import sys

# Add statphys_urban_learning to sys.path for local imports
curr = os.path.abspath('')
while curr != os.path.dirname(curr):
    if 'statphys_urban_learning' in os.listdir(curr):
        target = os.path.join(curr, 'statphys_urban_learning')
        if target not in sys.path:
            sys.path.insert(0, target)
        break
    curr = os.path.dirname(curr)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from exercises.src.ising import simulate_ising, heat_capacity, susceptibility, binder_cumulant

# %% [markdown]
# ## 1) 对多个系统尺寸做 \(\beta\) 扫描

# %%
# 提示：这是一版“能跑通”的最小设置。如果你想要更干净的峰值/塌缩，需要增大 n_sweeps 并改进自相关诊断。
betas = np.linspace(0.35, 0.55, 11)
Ls = [8, 12, 16, 20]

n_sweeps = 1500
burn_in = 500
thin = 10

rows = []
for L in Ls:
    for beta in betas:
        seed = int(L * 100_000 + int(round(float(beta), 4) * 10_000))
        tr = simulate_ising(L, beta, n_sweeps=n_sweeps, burn_in=burn_in, thin=thin, seed=seed)
        n_spins = L * L
        Cv = heat_capacity(beta, tr.energy, n_spins=n_spins)
        chi = susceptibility(beta, tr.magnetization, n_spins=n_spins)
        U = binder_cumulant(tr.magnetization)
        rows.append({"L": L, "beta": float(beta), "Cv": Cv, "chi": chi, "binder": U})

df = pd.DataFrame(rows)
df.head()

# %%
# Plot Cv
plt.figure()
for L in Ls:
    sub = df[df["L"] == L]
    plt.plot(sub["beta"], sub["Cv"], marker="o", label=f"L={L}")
plt.xlabel("beta")
plt.ylabel("Cv / N")
plt.title("Heat capacity per spin vs beta")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot susceptibility
plt.figure()
for L in Ls:
    sub = df[df["L"] == L]
    plt.plot(sub["beta"], sub["chi"], marker="o", label=f"L={L}")
plt.xlabel("beta")
plt.ylabel("chi per spin")
plt.title("Susceptibility per spin vs beta")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plot Binder cumulant
plt.figure()
for L in Ls:
    sub = df[df["L"] == L]
    plt.plot(sub["beta"], sub["binder"], marker="o", label=f"L={L}")
plt.xlabel("beta")
plt.ylabel("Binder cumulant U")
plt.title("Binder cumulant vs beta")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Very rough "peak" estimates (finite-size)
peak_Cv = df.loc[df.groupby("L")["Cv"].idxmax(), ["L","beta","Cv"]].sort_values("L")
peak_chi = df.loc[df.groupby("L")["chi"].idxmax(), ["L","beta","chi"]].sort_values("L")

peak_Cv, peak_chi

# %% [markdown]
# ## 2) 有限尺寸标度：\(\chi\) 的 data collapse（最小版）
#
# 为了把“塌缩”做成一个最小闭环，我们先用 2D Ising 的已知指数及临界点作为基准（你也可以改成用 Binder 交点估计 \(\beta_c\)）。
#
# - \(T_c \approx 2.269\), \(\beta_c \approx 0.4407\)
# - \(\nu=1\), \(\gamma/\nu=7/4\)

# %%
df = df.copy()
df["T"] = 1.0 / df["beta"]

Tc = 2.269185314213022
nu = 1.0
gamma_over_nu = 1.75

plt.figure()
for L in Ls:
    sub = df[df["L"] == L].copy()
    t = (sub["T"] - Tc) / Tc
    x = t * (L ** (1.0 / nu))
    y = sub["chi"] * (L ** (-gamma_over_nu))
    plt.plot(x, y, marker="o", label=f"L={L}")

plt.axvline(0.0, color="k", lw=1, alpha=0.3)
plt.xlabel(r"x = (T-Tc)/Tc * L^(1/nu)")
plt.ylabel(r"y = chi * L^(-gamma/nu)")
plt.title("FSS data collapse (using known Tc, nu, gamma/nu)")
plt.grid(True)
plt.legend()
plt.show()

chi_max = df.groupby("L")["chi"].max().sort_index()
Ls_arr = chi_max.index.to_numpy(dtype=float)
slope, intercept = np.polyfit(np.log(Ls_arr), np.log(chi_max.values), 1)
print("chi_max(L) ~ L^{gamma/nu}: gamma/nu (rough) =", slope)
chi_max

# %% [markdown]
# ## 讨论（写在你的记录里）
# - 峰值位置随 L 是否有漂移？这就是有限尺寸效应的直观表现。
# - Binder 曲线是否在某个 β 区间接近交点？你会如何用它估计临界附近区间？
# - 你做出了 data collapse 吗？如果曲线无法很好地塌缩，大概是什么原因？（有限尺寸太小？采样自相关太强？\(T_c\) 偏了？指数偏了？）
# - 为什么这里称它们是“proxy”？（提示：有限尺寸、采样误差、自相关）
